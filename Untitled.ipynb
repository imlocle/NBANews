# %%
# !pip install HTMLparser
# Out:
# ...
#   Running setup.py bdist_wheel for HTMLparser ... done
#   Stored in directory: /Users/locle/Library/Caches/pip/wheels/45/c6/28/0798e85dc732bad97e44033e85be73a8945f3e4b36511d6247
# Successfully built HTMLparser
# ...

# %%
from bs4 import BeautifulSoup as soup
import requests
import html

# %%
espn_nba_url="http://www.espn.com/nba/"

espn_call = requests.get(espn_nba_url).text
espn_html = soup(espn_call, 'html.parser')
print (espn_html.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-icon-fonts">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
#   <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="http://www.espn.com/nba/" rel="canonical"/>
#   <title>
#    NBA - National Basketball Association Teams, Scores, Stats, News, Standings, Rumors - ESPN
#   </title>
#   <meta content="Get the latest NBA basketball news, scores, stats, standings, fantasy games, and more from ESPN." name="description">
#    <meta content="nba, national basketball association, pro basketball, nba basketball" name="news_keywords"/>
#    <meta content="nba, national basketball association, pro basketball, nba basketball" name="keywords"/>
#    <meta content="116656161708917" property="fb:app_id"/>
#    <meta content="ESPN.com" property="og:site_name"/>
# ...

# %%
test = espn_html.find_all("div", "contentItem__contentWrapper")
test_two = espn_html.find_all("section", "contentItem__content contentItem__content--story has-image contentItem__content--collection")

# %%
html.unescape(test_two[0])
# Out:
# <section class="contentItem__content contentItem__content--story has-image contentItem__content--collection"><a class="contentItem__padding" data-id="22369212" data-mporder='{"desktop":"image-story","mobile":"story-image"}' href="/nba/story/_/id/22369212/zach-lowe-lebron-james-cleveland-cavaliers-2018-nba-trade-deadline" name="&amp;lpos=nba:feed:xx:coll:multi:2:story"><div class="contentItem__contentWrapper"><h1 class="contentItem__title contentItem__title--story" data-mptype="story">Lowe: The Cavs' imperfect deadline was the best they could do</h1><p class="contentItem__subhead contentItem__subhead--story">Can Cleveland get back to the NBA Finals and compete with Golden State? Zach Lowe looks at the three trades that might make it possible.</p></div><figure class="media-wrapper"><picture class="media-wrapper_image"><source data-srcset="http://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2018%2F0115%2Fr314901_1296x1296_1%2D1.jpg&amp;w=90&amp;h=90&amp;scale=crop&amp;cquality=80&amp;locati
# ...

# %%
test_two[0]
# Out:
# <section class="contentItem__content contentItem__content--story has-image contentItem__content--collection"><a class="contentItem__padding" data-id="22369212" data-mporder='{"desktop":"image-story","mobile":"story-image"}' href="/nba/story/_/id/22369212/zach-lowe-lebron-james-cleveland-cavaliers-2018-nba-trade-deadline" name="&amp;lpos=nba:feed:xx:coll:multi:2:story"><div class="contentItem__contentWrapper"><h1 class="contentItem__title contentItem__title--story" data-mptype="story">Lowe: The Cavs' imperfect deadline was the best they could do</h1><p class="contentItem__subhead contentItem__subhead--story">Can Cleveland get back to the NBA Finals and compete with Golden State? Zach Lowe looks at the three trades that might make it possible.</p></div><figure class="media-wrapper"><picture class="media-wrapper_image"><source data-srcset="http://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2018%2F0115%2Fr314901_1296x1296_1%2D1.jpg&amp;w=90&amp;h=90&amp;scale=crop&amp;cquality=80&amp;locati
# ...
